# %% [markdown]
# # Conditional GLOW for Cell Data Generation

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Create output directory
os.makedirs("generated", exist_ok=True)

torch.manual_seed(42)
np.random.seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# %% [markdown]
# ## 2. Load and Preprocess

# %%
def load_and_preprocess_data(data_path='input/ML_data.csv'):
    df = pd.read_csv(data_path).drop(columns=['Samples'])
    df = df[~df['Cell_type'].isin(['Unknown'])]

    feature_names = df.columns.drop('Cell_type')
    le = LabelEncoder()
    df['Cell_type'] = le.fit_transform(df['Cell_type'])
    label_names = le.classes_
    num_classes = len(label_names)

    y = df['Cell_type'].values
    X = df.drop(columns=['Cell_type']).values
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    X_train, X_val, y_train, y_val = train_test_split(
        X_scaled, y, test_size=0.2, random_state=42, stratify=y
    )

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)

    train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=64, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=64, shuffle=False)

    return X, y, X_scaled, scaler, le, label_names, feature_names, num_classes, train_loader, val_loader

X, y, X_scaled, scaler, le, label_names, feature_names, num_classes, train_loader, val_loader = load_and_preprocess_data()
input_dim = X.shape[1]
print(f"Input dimension: {input_dim}, Number of classes: {num_classes}")

# %% [markdown]
# ## 3. Model Components

# %%
import torch.nn as nn
import torch.nn.utils.spectral_norm as spectral_norm

class MLP(nn.Module):
    def __init__(self, in_features, hidden_features, out_features):
        super().__init__()
        self.net = nn.Sequential(
            spectral_norm(nn.Linear(in_features, hidden_features)),  # Spectral Norm added
            nn.GELU(),
            nn.LayerNorm(hidden_features),
            spectral_norm(nn.Linear(hidden_features, hidden_features)),  # Spectral Norm added
            nn.GELU(),
            spectral_norm(nn.Linear(hidden_features, out_features)),  # Spectral Norm added
        )
    
    def forward(self, x):
        return self.net(x)

class ActNorm(nn.Module):
    def __init__(self, features, scale=1.0):
        super().__init__()
        self.initialized = False
        self.scale = scale
        self.register_parameter("bias", nn.Parameter(torch.zeros(features)))
        self.register_parameter("logs", nn.Parameter(torch.zeros(features)))

    def initialize(self, x):
        with torch.no_grad():
            mean = x.mean(0)
            std = x.std(0)
            self.bias.data.copy_(-mean)
            self.logs.data.copy_(torch.log(self.scale / (std + 1e-6)))
        self.initialized = True

    def forward(self, x):
        if not self.initialized:
            self.initialize(x)
        z = (x + self.bias) * torch.exp(self.logs)
        return z, self.logs.sum()

    def inverse(self, z):
        return (z * torch.exp(-self.logs)) - self.bias

class InvertibleLinear(nn.Module):
    def __init__(self, dim):
        super().__init__()
        W = torch.nn.init.orthogonal_(torch.randn(dim, dim))
        P, L, U = torch.lu_unpack(*W.lu())
        self.register_buffer('P', P)
        self.L = nn.Parameter(L)
        self.S = nn.Parameter(U.diag())
        self.U = nn.Parameter(torch.triu(U, diagonal=1))

    def _assemble_W(self):
        L = torch.tril(self.L, -1) + torch.eye(self.L.size(0), device=self.L.device)
        U = torch.triu(self.U, 1) + torch.diag(self.S)
        return self.P @ L @ U

    def forward(self, x):
        W = self._assemble_W()
        return x @ W, torch.sum(torch.log(torch.clamp(torch.abs(self.S), min=1e-6)))

    def inverse(self, z):
        W = self._assemble_W()
        return z @ torch.inverse(W)

class AffineCoupling(nn.Module):
    def __init__(self, input_dim, hidden_dim, mask, class_embedding):
        super().__init__()
        self.mask = mask
        self.embedding = class_embedding  # shared!
        self.scale_net = MLP(input_dim + 8, hidden_dim, input_dim)
        self.translate_net = MLP(input_dim + 8, hidden_dim, input_dim)


    def forward(self, x, y):
        x_masked = x * self.mask
        y_embed = self.embedding(y)
        x_cat = torch.cat([x_masked, y_embed], dim=1)
        scale = self.scale_net(x_cat) * (1 - self.mask)
        translate = self.translate_net(x_cat) * (1 - self.mask)
        y_out = x_masked + (1 - self.mask) * (x * torch.exp(scale) + translate)
        return y_out, scale.sum(1)

    def inverse(self, y, label):
        y_masked = y * self.mask
        y_embed = self.embedding(label)
        y_cat = torch.cat([y_masked, y_embed], dim=1)
        scale = self.scale_net(y_cat) * (1 - self.mask)
        translate = self.translate_net(y_cat) * (1 - self.mask)
        x = y_masked + (1 - self.mask) * (y - translate) * torch.exp(-scale)
        return x


class GlowStep(nn.Module):
    def __init__(self, input_dim, hidden_dim, mask, class_embedding):
        super().__init__()
        self.actnorm = ActNorm(input_dim)
        self.invconv = InvertibleLinear(input_dim)
        self.coupling = AffineCoupling(input_dim, hidden_dim, mask, class_embedding)


    def forward(self, x, y):
        x, ldj1 = self.actnorm(x)
        x, ldj2 = self.invconv(x)
        x, ldj3 = self.coupling(x, y)
        return x, ldj1 + ldj2 + ldj3

    def inverse(self, z, y):
        z = self.coupling.inverse(z, y)
        z = self.invconv.inverse(z)
        z = self.actnorm.inverse(z)
        return z

class ConditionalGLOW(nn.Module):
    def __init__(self, input_dim, hidden_dim, n_flow_steps, num_classes):
        super().__init__()
        self.class_embedding = nn.Embedding(num_classes, 8)  # shared embedding
        self.flow_steps = nn.ModuleList()
        for i in range(n_flow_steps):
            mask = torch.zeros(input_dim).to(device)
            mask[i % 2::2] = 1
            self.flow_steps.append(
                GlowStep(input_dim, hidden_dim, mask, self.class_embedding)
            )

    def forward(self, x, y):
        log_det = 0
        for step in self.flow_steps:
            x, ldj = step(x, y)
            log_det += ldj
        return x, log_det

    def inverse(self, z, y):
        for step in reversed(self.flow_steps):
            z = step.inverse(z, y)
        return z

# %% [markdown]
# ## 4. Training

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import mean_squared_error, mean_absolute_error, roc_auc_score
import numpy as np

# Loss functions for additional metrics
def cosine_similarity_loss(real, generated):
    return 1 - F.cosine_similarity(real, generated).mean()

def mean_absolute_error_loss(real, generated):
    return F.l1_loss(real, generated).mean()

def mean_squared_error_loss(real, generated):
    return F.mse_loss(real, generated).mean()

import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# Initialize the model and optimizer
hidden_dim = 128
n_flow_steps = 16
model = ConditionalGLOW(input_dim, hidden_dim, n_flow_steps, num_classes).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Set up the learning rate scheduler
scheduler = StepLR(optimizer, step_size=100, gamma=0.5) 

# Modify the training loop to include the scheduler step
def train(model, train_loader, optimizer, scheduler, num_epochs):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        total_cosine_loss = 0
        total_mse_loss = 0
        total_mae_loss = 0
        total_nll_loss = 0
        total_samples = 0
        
        for x_batch, y_batch in train_loader:
            optimizer.zero_grad()
            
            # Forward pass
            z, log_det = model(x_batch, y_batch)
            log_prob = -0.5 * torch.sum(z ** 2, dim=1) - 0.5 * input_dim * np.log(2 * np.pi)
            nll_loss = -(log_prob + log_det).mean()
            
            # Compute additional loss metrics
            mse_loss = mean_squared_error_loss(x_batch, z)  # MSE between original and generated data
            mae_loss = mean_absolute_error_loss(x_batch, z)  # MAE between original and generated data
            cosine_loss = cosine_similarity_loss(x_batch, z)  # Cosine similarity between original and generated data

            # Total loss is a combination of all metrics
            total_loss = nll_loss + mse_loss + mae_loss + cosine_loss

            # Backward pass and optimization
            total_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.step()
            
            # Accumulate the metrics for reporting
            total_samples += x_batch.size(0)
            total_nll_loss += nll_loss.item() * x_batch.size(0)
            total_mse_loss += mse_loss.item() * x_batch.size(0)
            total_mae_loss += mae_loss.item() * x_batch.size(0)
            total_cosine_loss += cosine_loss.item() * x_batch.size(0)
        
        # Compute average losses
        avg_nll_loss = total_nll_loss / total_samples
        avg_mse_loss = total_mse_loss / total_samples
        avg_mae_loss = total_mae_loss / total_samples
        avg_cosine_loss = total_cosine_loss / total_samples

        print(f"Epoch {epoch+1}/{num_epochs}, NLL Loss: {avg_nll_loss:.4f}, MSE Loss: {avg_mse_loss:.4f}, "
              f"MAE Loss: {avg_mae_loss:.4f}, Cosine Similarity Loss: {avg_cosine_loss:.4f}")

        # Step the scheduler after every epoch
        scheduler.step()

# Train the model
train(model, train_loader, optimizer, scheduler, num_epochs=300)

torch.save(model.state_dict(), "generated/glow_model.pt")
# Out:
# Using device: cuda
# Input dimension: 89, Number of classes: 4
# /home/thomas/miniconda3/envs/DeepN/lib/python3.12/site-packages/torch/_tensor.py:902: UserWarning: torch.lu is deprecated in favor of torch.linalg.lu_factor / torch.linalg.lu_factor_ex and will be removed in a future PyTorch release.
# LU, pivots = torch.lu(A, compute_pivots)
# should be replaced with
# LU, pivots = torch.linalg.lu_factor(A, compute_pivots)
# and
# LU, pivots, info = torch.lu(A, compute_pivots, get_infos=True)
# should be replaced with
# LU, pivots, info = torch.linalg.lu_factor_ex(A, compute_pivots) (Triggered internally at /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:2053.)
#   LU, pivots, infos = torch._lu_with_info(
# Epoch 1/300, NLL Loss: 154.1673, MSE Loss: 1.9010, MAE Loss: 1.0792, Cosine Similarity Loss: 1.0002
# Epoch 2/300, NLL Loss: 116.2647, MSE Loss: 1.9060, MAE Loss: 1.0874, Cosine Similarity Loss: 0.9628
# Epoch 3/300, NLL Loss: 103.9520, MSE Loss: 1.8852, MAE Loss: 1.0824, Cosine Similarity Loss: 0.9551
# Epoch 4/300, NLL Loss: 97.4139, MSE Loss: 1.8432, MAE Loss: 1.0710, Cosine Similarity Loss: 0.9269
# Epoch 5/300, NLL Loss: 92.4542, MSE Loss: 1.8027, MAE Loss: 1.0587, Cosine Similarity Loss: 0.9057
# Epoch 6/300, NLL Loss: 87.6841, MSE Loss: 1.7892, MAE Loss: 1.0533, Cosine Similarity Loss: 0.8947
# Epoch 7/300, NLL Loss: 82.4833, MSE Loss: 1.7561, MAE Loss: 1.0437, Cosine Similarity Loss: 0.8813
# Epoch 8/300, NLL Loss: 77.4173, MSE Loss: 1.7429, MAE Loss: 1.0399, Cosine Similarity Loss: 0.8799
# Epoch 9/300, NLL Loss: 73.5053, MSE Loss: 1.7263, MAE Loss: 1.0355, Cosine Similarity Loss: 0.8744
# Epoch 10/300, NLL Loss: 69.8689, MSE Loss: 1.7246, MAE Loss: 1.0371, Cosine Similarity Loss: 0.8766
# Epoch 11/300, NLL Loss: 67.6976, MSE Loss: 1.7483, MAE Loss: 1.0415, Cosine Similarity Loss: 0.8782
# Epoch 12/300, NLL Loss: 63.9699, MSE Loss: 1.7367, MAE Loss: 1.0401, Cosine Similarity Loss: 0.8828
# Epoch 13/300, NLL Loss: 61.5841, MSE Loss: 1.7428, MAE Loss: 1.0396, Cosine Similarity Loss: 0.8767
# Epoch 14/300, NLL Loss: 59.1084, MSE Loss: 1.7140, MAE Loss: 1.0297, Cosine Similarity Loss: 0.8724
# Epoch 15/300, NLL Loss: 56.8052, MSE Loss: 1.7432, MAE Loss: 1.0418, Cosine Similarity Loss: 0.8709
# Epoch 16/300, NLL Loss: 54.7012, MSE Loss: 1.7101, MAE Loss: 1.0339, Cosine Similarity Loss: 0.8688
# Epoch 17/300, NLL Loss: 53.5887, MSE Loss: 1.7353, MAE Loss: 1.0386, Cosine Similarity Loss: 0.8721
# Epoch 18/300, NLL Loss: 51.0505, MSE Loss: 1.7089, MAE Loss: 1.0310, Cosine Similarity Loss: 0.8640
# Epoch 19/300, NLL Loss: 50.3078, MSE Loss: 1.7232, MAE Loss: 1.0349, Cosine Similarity Loss: 0.8652
# Epoch 20/300, NLL Loss: 46.7996, MSE Loss: 1.6981, MAE Loss: 1.0289, Cosine Similarity Loss: 0.8603
# Epoch 21/300, NLL Loss: 46.2388, MSE Loss: 1.7159, MAE Loss: 1.0338, Cosine Similarity Loss: 0.8570
# Epoch 22/300, NLL Loss: 45.6579, MSE Loss: 1.7076, MAE Loss: 1.0296, Cosine Similarity Loss: 0.8617
# Epoch 23/300, NLL Loss: 43.4616, MSE Loss: 1.6897, MAE Loss: 1.0243, Cosine Similarity Loss: 0.8531
# Epoch 24/300, NLL Loss: 41.7900, MSE Loss: 1.7144, MAE Loss: 1.0348, Cosine Similarity Loss: 0.8613
# Epoch 25/300, NLL Loss: 42.3480, MSE Loss: 1.6858, MAE Loss: 1.0242, Cosine Similarity Loss: 0.8535
# Epoch 26/300, NLL Loss: 40.6533, MSE Loss: 1.7244, MAE Loss: 1.0367, Cosine Similarity Loss: 0.8633
# Epoch 27/300, NLL Loss: 38.7628, MSE Loss: 1.6954, MAE Loss: 1.0282, Cosine Similarity Loss: 0.8513
# Epoch 28/300, NLL Loss: 37.3224, MSE Loss: 1.6846, MAE Loss: 1.0235, Cosine Similarity Loss: 0.8531
# Epoch 29/300, NLL Loss: 36.1894, MSE Loss: 1.6877, MAE Loss: 1.0257, Cosine Similarity Loss: 0.8500
# Epoch 30/300, NLL Loss: 34.9712, MSE Loss: 1.7008, MAE Loss: 1.0290, Cosine Similarity Loss: 0.8525
# Epoch 31/300, NLL Loss: 35.1009, MSE Loss: 1.7020, MAE Loss: 1.0311, Cosine Similarity Loss: 0.8525
# Epoch 32/300, NLL Loss: 33.6150, MSE Loss: 1.6739, MAE Loss: 1.0200, Cosine Similarity Loss: 0.8500
# Epoch 33/300, NLL Loss: 31.4968, MSE Loss: 1.6965, MAE Loss: 1.0281, Cosine Similarity Loss: 0.8475
# Epoch 34/300, NLL Loss: 30.5273, MSE Loss: 1.6902, MAE Loss: 1.0256, Cosine Similarity Loss: 0.8477
# Epoch 35/300, NLL Loss: 31.1702, MSE Loss: 1.6986, MAE Loss: 1.0297, Cosine Similarity Loss: 0.8594
# Epoch 36/300, NLL Loss: 29.1463, MSE Loss: 1.6869, MAE Loss: 1.0236, Cosine Similarity Loss: 0.8509
# Epoch 37/300, NLL Loss: 28.0662, MSE Loss: 1.6594, MAE Loss: 1.0170, Cosine Similarity Loss: 0.8372
# Epoch 38/300, NLL Loss: 28.6569, MSE Loss: 1.7035, MAE Loss: 1.0313, Cosine Similarity Loss: 0.8545
# Epoch 39/300, NLL Loss: 26.5656, MSE Loss: 1.6719, MAE Loss: 1.0203, Cosine Similarity Loss: 0.8384
# Epoch 40/300, NLL Loss: 26.2789, MSE Loss: 1.6825, MAE Loss: 1.0237, Cosine Similarity Loss: 0.8419
# Epoch 41/300, NLL Loss: 25.5880, MSE Loss: 1.6688, MAE Loss: 1.0164, Cosine Similarity Loss: 0.8445
# Epoch 42/300, NLL Loss: 24.0396, MSE Loss: 1.6719, MAE Loss: 1.0183, Cosine Similarity Loss: 0.8397
# Epoch 43/300, NLL Loss: 22.2941, MSE Loss: 1.6873, MAE Loss: 1.0262, Cosine Similarity Loss: 0.8463
# Epoch 44/300, NLL Loss: 22.2116, MSE Loss: 1.6855, MAE Loss: 1.0249, Cosine Similarity Loss: 0.8482
# Epoch 45/300, NLL Loss: 22.3055, MSE Loss: 1.6632, MAE Loss: 1.0160, Cosine Similarity Loss: 0.8377
# Epoch 46/300, NLL Loss: 21.5204, MSE Loss: 1.6812, MAE Loss: 1.0227, Cosine Similarity Loss: 0.8477
# Epoch 47/300, NLL Loss: 20.8639, MSE Loss: 1.6653, MAE Loss: 1.0177, Cosine Similarity Loss: 0.8352
# Epoch 48/300, NLL Loss: 19.5326, MSE Loss: 1.6721, MAE Loss: 1.0187, Cosine Similarity Loss: 0.8400
# Epoch 49/300, NLL Loss: 18.4931, MSE Loss: 1.6678, MAE Loss: 1.0199, Cosine Similarity Loss: 0.8404
# Epoch 50/300, NLL Loss: 19.0402, MSE Loss: 1.6789, MAE Loss: 1.0210, Cosine Similarity Loss: 0.8382
# Epoch 51/300, NLL Loss: 19.1020, MSE Loss: 1.6572, MAE Loss: 1.0166, Cosine Similarity Loss: 0.8398
# Epoch 52/300, NLL Loss: 17.9390, MSE Loss: 1.6681, MAE Loss: 1.0220, Cosine Similarity Loss: 0.8379
# Epoch 53/300, NLL Loss: 16.7216, MSE Loss: 1.6703, MAE Loss: 1.0205, Cosine Similarity Loss: 0.8398
# Epoch 54/300, NLL Loss: 16.3688, MSE Loss: 1.6839, MAE Loss: 1.0242, Cosine Similarity Loss: 0.8392
# Epoch 55/300, NLL Loss: 16.3044, MSE Loss: 1.6841, MAE Loss: 1.0255, Cosine Similarity Loss: 0.8469
# Epoch 56/300, NLL Loss: 15.7329, MSE Loss: 1.6597, MAE Loss: 1.0165, Cosine Similarity Loss: 0.8367
# Epoch 57/300, NLL Loss: 15.3105, MSE Loss: 1.6728, MAE Loss: 1.0221, Cosine Similarity Loss: 0.8382
# Epoch 58/300, NLL Loss: 13.9309, MSE Loss: 1.6623, MAE Loss: 1.0185, Cosine Similarity Loss: 0.8373
# Epoch 59/300, NLL Loss: 12.6610, MSE Loss: 1.6578, MAE Loss: 1.0168, Cosine Similarity Loss: 0.8321
# Epoch 60/300, NLL Loss: 13.5957, MSE Loss: 1.6677, MAE Loss: 1.0201, Cosine Similarity Loss: 0.8370
# Epoch 61/300, NLL Loss: 11.4171, MSE Loss: 1.6565, MAE Loss: 1.0164, Cosine Similarity Loss: 0.8421
# Epoch 62/300, NLL Loss: 12.3099, MSE Loss: 1.6737, MAE Loss: 1.0201, Cosine Similarity Loss: 0.8349
# Epoch 63/300, NLL Loss: 11.1054, MSE Loss: 1.6449, MAE Loss: 1.0124, Cosine Similarity Loss: 0.8319
# Epoch 64/300, NLL Loss: 10.3147, MSE Loss: 1.6933, MAE Loss: 1.0250, Cosine Similarity Loss: 0.8474
# Epoch 65/300, NLL Loss: 10.4983, MSE Loss: 1.6437, MAE Loss: 1.0112, Cosine Similarity Loss: 0.8331
# Epoch 66/300, NLL Loss: 9.6820, MSE Loss: 1.6620, MAE Loss: 1.0157, Cosine Similarity Loss: 0.8299
# Epoch 67/300, NLL Loss: 10.6805, MSE Loss: 1.6481, MAE Loss: 1.0161, Cosine Similarity Loss: 0.8266
# Epoch 68/300, NLL Loss: 9.0028, MSE Loss: 1.6733, MAE Loss: 1.0232, Cosine Similarity Loss: 0.8382
# Epoch 69/300, NLL Loss: 9.6522, MSE Loss: 1.6648, MAE Loss: 1.0185, Cosine Similarity Loss: 0.8394
# Epoch 70/300, NLL Loss: 9.0127, MSE Loss: 1.6518, MAE Loss: 1.0160, Cosine Similarity Loss: 0.8296
# Epoch 71/300, NLL Loss: 9.9503, MSE Loss: 1.6776, MAE Loss: 1.0213, Cosine Similarity Loss: 0.8358
# Epoch 72/300, NLL Loss: 8.4092, MSE Loss: 1.6321, MAE Loss: 1.0096, Cosine Similarity Loss: 0.8263
# Epoch 73/300, NLL Loss: 9.1784, MSE Loss: 1.6790, MAE Loss: 1.0237, Cosine Similarity Loss: 0.8403
# Epoch 74/300, NLL Loss: 7.2807, MSE Loss: 1.6510, MAE Loss: 1.0147, Cosine Similarity Loss: 0.8311
# Epoch 75/300, NLL Loss: 6.5650, MSE Loss: 1.6591, MAE Loss: 1.0164, Cosine Similarity Loss: 0.8319
# Epoch 76/300, NLL Loss: 6.7473, MSE Loss: 1.6462, MAE Loss: 1.0134, Cosine Similarity Loss: 0.8311
# Epoch 77/300, NLL Loss: 6.1103, MSE Loss: 1.6513, MAE Loss: 1.0149, Cosine Similarity Loss: 0.8275
# Epoch 78/300, NLL Loss: 5.2723, MSE Loss: 1.6529, MAE Loss: 1.0125, Cosine Similarity Loss: 0.8297
# Epoch 79/300, NLL Loss: 5.3338, MSE Loss: 1.6572, MAE Loss: 1.0155, Cosine Similarity Loss: 0.8323
# Epoch 80/300, NLL Loss: 4.2356, MSE Loss: 1.6509, MAE Loss: 1.0131, Cosine Similarity Loss: 0.8321
# Epoch 81/300, NLL Loss: 4.8529, MSE Loss: 1.6729, MAE Loss: 1.0173, Cosine Similarity Loss: 0.8379
# Epoch 82/300, NLL Loss: 4.0381, MSE Loss: 1.6372, MAE Loss: 1.0111, Cosine Similarity Loss: 0.8204
# Epoch 83/300, NLL Loss: 3.3855, MSE Loss: 1.6735, MAE Loss: 1.0219, Cosine Similarity Loss: 0.8383
# Epoch 84/300, NLL Loss: 3.0659, MSE Loss: 1.6500, MAE Loss: 1.0128, Cosine Similarity Loss: 0.8306
# Epoch 85/300, NLL Loss: 1.8706, MSE Loss: 1.6525, MAE Loss: 1.0155, Cosine Similarity Loss: 0.8336
# Epoch 86/300, NLL Loss: 2.5500, MSE Loss: 1.6607, MAE Loss: 1.0168, Cosine Similarity Loss: 0.8311
# Epoch 87/300, NLL Loss: 2.6255, MSE Loss: 1.6503, MAE Loss: 1.0154, Cosine Similarity Loss: 0.8300
# Epoch 88/300, NLL Loss: 1.2317, MSE Loss: 1.6464, MAE Loss: 1.0136, Cosine Similarity Loss: 0.8217
# Epoch 89/300, NLL Loss: 1.8179, MSE Loss: 1.6566, MAE Loss: 1.0157, Cosine Similarity Loss: 0.8333
# Epoch 90/300, NLL Loss: 0.6360, MSE Loss: 1.6625, MAE Loss: 1.0166, Cosine Similarity Loss: 0.8320
# Epoch 91/300, NLL Loss: -0.4686, MSE Loss: 1.6237, MAE Loss: 1.0052, Cosine Similarity Loss: 0.8185
# Epoch 92/300, NLL Loss: -0.0153, MSE Loss: 1.6745, MAE Loss: 1.0202, Cosine Similarity Loss: 0.8377
# Epoch 93/300, NLL Loss: 0.3738, MSE Loss: 1.6335, MAE Loss: 1.0079, Cosine Similarity Loss: 0.8170
# Epoch 94/300, NLL Loss: -0.1422, MSE Loss: 1.6635, MAE Loss: 1.0158, Cosine Similarity Loss: 0.8389
# Epoch 95/300, NLL Loss: -0.5603, MSE Loss: 1.6413, MAE Loss: 1.0079, Cosine Similarity Loss: 0.8284
# Epoch 96/300, NLL Loss: -0.7803, MSE Loss: 1.6681, MAE Loss: 1.0206, Cosine Similarity Loss: 0.8306
# Epoch 97/300, NLL Loss: -2.3081, MSE Loss: 1.6200, MAE Loss: 1.0037, Cosine Similarity Loss: 0.8182
# Epoch 98/300, NLL Loss: -3.2388, MSE Loss: 1.6679, MAE Loss: 1.0201, Cosine Similarity Loss: 0.8417
# Epoch 99/300, NLL Loss: -2.9966, MSE Loss: 1.6439, MAE Loss: 1.0126, Cosine Similarity Loss: 0.8191
# Epoch 100/300, NLL Loss: -2.9784, MSE Loss: 1.6427, MAE Loss: 1.0106, Cosine Similarity Loss: 0.8312
# Epoch 101/300, NLL Loss: -11.1539, MSE Loss: 1.5451, MAE Loss: 0.9813, Cosine Similarity Loss: 0.8193
# Epoch 102/300, NLL Loss: -28.4785, MSE Loss: 1.4872, MAE Loss: 0.9618, Cosine Similarity Loss: 0.8134
# Epoch 103/300, NLL Loss: -36.4183, MSE Loss: 1.5515, MAE Loss: 0.9825, Cosine Similarity Loss: 0.8195
# Epoch 104/300, NLL Loss: -41.3095, MSE Loss: 1.5513, MAE Loss: 0.9833, Cosine Similarity Loss: 0.8095
# Epoch 105/300, NLL Loss: -42.7417, MSE Loss: 1.5839, MAE Loss: 0.9934, Cosine Similarity Loss: 0.8071
# Epoch 106/300, NLL Loss: -43.7236, MSE Loss: 1.5860, MAE Loss: 0.9933, Cosine Similarity Loss: 0.8225
# Epoch 107/300, NLL Loss: -46.4108, MSE Loss: 1.5686, MAE Loss: 0.9908, Cosine Similarity Loss: 0.8099
# Epoch 108/300, NLL Loss: -46.6023, MSE Loss: 1.6102, MAE Loss: 1.0032, Cosine Similarity Loss: 0.8177
# Epoch 109/300, NLL Loss: -47.0495, MSE Loss: 1.5901, MAE Loss: 0.9974, Cosine Similarity Loss: 0.8196
# Epoch 110/300, NLL Loss: -48.9220, MSE Loss: 1.5915, MAE Loss: 0.9947, Cosine Similarity Loss: 0.8142
# Epoch 111/300, NLL Loss: -49.0393, MSE Loss: 1.6217, MAE Loss: 1.0064, Cosine Similarity Loss: 0.8284
# Epoch 112/300, NLL Loss: -47.6546, MSE Loss: 1.6093, MAE Loss: 1.0004, Cosine Similarity Loss: 0.8140
# Epoch 113/300, NLL Loss: -49.1404, MSE Loss: 1.6143, MAE Loss: 1.0036, Cosine Similarity Loss: 0.8291
# Epoch 114/300, NLL Loss: -47.8879, MSE Loss: 1.6209, MAE Loss: 1.0069, Cosine Similarity Loss: 0.8096
# Epoch 115/300, NLL Loss: -49.8734, MSE Loss: 1.5945, MAE Loss: 0.9966, Cosine Similarity Loss: 0.8231
# Epoch 116/300, NLL Loss: -49.5792, MSE Loss: 1.6271, MAE Loss: 1.0053, Cosine Similarity Loss: 0.8173
# Epoch 117/300, NLL Loss: -49.8569, MSE Loss: 1.6080, MAE Loss: 1.0032, Cosine Similarity Loss: 0.8220
# Epoch 118/300, NLL Loss: -49.1162, MSE Loss: 1.6344, MAE Loss: 1.0091, Cosine Similarity Loss: 0.8226
# Epoch 119/300, NLL Loss: -50.1277, MSE Loss: 1.6159, MAE Loss: 1.0014, Cosine Similarity Loss: 0.8226
# Epoch 120/300, NLL Loss: -50.2295, MSE Loss: 1.6281, MAE Loss: 1.0053, Cosine Similarity Loss: 0.8210
# Epoch 121/300, NLL Loss: -50.2131, MSE Loss: 1.6009, MAE Loss: 1.0001, Cosine Similarity Loss: 0.8183
# Epoch 122/300, NLL Loss: -50.6579, MSE Loss: 1.6339, MAE Loss: 1.0086, Cosine Similarity Loss: 0.8145
# Epoch 123/300, NLL Loss: -49.4359, MSE Loss: 1.6579, MAE Loss: 1.0164, Cosine Similarity Loss: 0.8349
# Epoch 124/300, NLL Loss: -50.7454, MSE Loss: 1.5807, MAE Loss: 0.9929, Cosine Similarity Loss: 0.8072
# Epoch 125/300, NLL Loss: -51.0923, MSE Loss: 1.6388, MAE Loss: 1.0133, Cosine Similarity Loss: 0.8351
# Epoch 126/300, NLL Loss: -52.2604, MSE Loss: 1.6148, MAE Loss: 1.0025, Cosine Similarity Loss: 0.8175
# Epoch 127/300, NLL Loss: -51.8583, MSE Loss: 1.6349, MAE Loss: 1.0130, Cosine Similarity Loss: 0.8256
# Epoch 128/300, NLL Loss: -52.3856, MSE Loss: 1.6239, MAE Loss: 1.0040, Cosine Similarity Loss: 0.8140
# Epoch 129/300, NLL Loss: -52.8513, MSE Loss: 1.6232, MAE Loss: 1.0063, Cosine Similarity Loss: 0.8270
# Epoch 130/300, NLL Loss: -52.0153, MSE Loss: 1.6275, MAE Loss: 1.0052, Cosine Similarity Loss: 0.8173
# Epoch 131/300, NLL Loss: -52.0784, MSE Loss: 1.6152, MAE Loss: 1.0062, Cosine Similarity Loss: 0.8196
# Epoch 132/300, NLL Loss: -52.0946, MSE Loss: 1.6255, MAE Loss: 1.0074, Cosine Similarity Loss: 0.8228
# Epoch 133/300, NLL Loss: -52.5995, MSE Loss: 1.6366, MAE Loss: 1.0109, Cosine Similarity Loss: 0.8254
# Epoch 134/300, NLL Loss: -53.3474, MSE Loss: 1.6083, MAE Loss: 1.0009, Cosine Similarity Loss: 0.8159
# Epoch 135/300, NLL Loss: -52.8981, MSE Loss: 1.6404, MAE Loss: 1.0138, Cosine Similarity Loss: 0.8265
# Epoch 136/300, NLL Loss: -53.6257, MSE Loss: 1.6291, MAE Loss: 1.0055, Cosine Similarity Loss: 0.8224
# Epoch 137/300, NLL Loss: -52.1374, MSE Loss: 1.6361, MAE Loss: 1.0097, Cosine Similarity Loss: 0.8196
# Epoch 138/300, NLL Loss: -54.9053, MSE Loss: 1.6136, MAE Loss: 1.0000, Cosine Similarity Loss: 0.8255
# Epoch 139/300, NLL Loss: -53.2768, MSE Loss: 1.6419, MAE Loss: 1.0109, Cosine Similarity Loss: 0.8198
# Epoch 140/300, NLL Loss: -53.3938, MSE Loss: 1.6139, MAE Loss: 1.0042, Cosine Similarity Loss: 0.8209
# Epoch 141/300, NLL Loss: -54.1706, MSE Loss: 1.6316, MAE Loss: 1.0073, Cosine Similarity Loss: 0.8211
# Epoch 142/300, NLL Loss: -54.7947, MSE Loss: 1.6222, MAE Loss: 1.0031, Cosine Similarity Loss: 0.8202
# Epoch 143/300, NLL Loss: -52.7980, MSE Loss: 1.6502, MAE Loss: 1.0143, Cosine Similarity Loss: 0.8247
# Epoch 144/300, NLL Loss: -53.9840, MSE Loss: 1.6200, MAE Loss: 1.0049, Cosine Similarity Loss: 0.8215
# Epoch 145/300, NLL Loss: -54.1264, MSE Loss: 1.6433, MAE Loss: 1.0114, Cosine Similarity Loss: 0.8214
# Epoch 146/300, NLL Loss: -53.6323, MSE Loss: 1.6206, MAE Loss: 1.0058, Cosine Similarity Loss: 0.8223
# Epoch 147/300, NLL Loss: -55.1377, MSE Loss: 1.6187, MAE Loss: 1.0057, Cosine Similarity Loss: 0.8219
# Epoch 148/300, NLL Loss: -56.1254, MSE Loss: 1.6053, MAE Loss: 0.9984, Cosine Similarity Loss: 0.8197
# Epoch 149/300, NLL Loss: -53.9765, MSE Loss: 1.6635, MAE Loss: 1.0176, Cosine Similarity Loss: 0.8235
# Epoch 150/300, NLL Loss: -54.6145, MSE Loss: 1.6245, MAE Loss: 1.0088, Cosine Similarity Loss: 0.8251
# Epoch 151/300, NLL Loss: -54.9068, MSE Loss: 1.6588, MAE Loss: 1.0193, Cosine Similarity Loss: 0.8364
# Epoch 152/300, NLL Loss: -54.8574, MSE Loss: 1.6291, MAE Loss: 1.0061, Cosine Similarity Loss: 0.8189
# Epoch 153/300, NLL Loss: -56.6804, MSE Loss: 1.6266, MAE Loss: 1.0080, Cosine Similarity Loss: 0.8292
# Epoch 154/300, NLL Loss: -56.2231, MSE Loss: 1.6137, MAE Loss: 1.0016, Cosine Similarity Loss: 0.8129
# Epoch 155/300, NLL Loss: -56.2509, MSE Loss: 1.6402, MAE Loss: 1.0080, Cosine Similarity Loss: 0.8268
# Epoch 156/300, NLL Loss: -55.1454, MSE Loss: 1.6657, MAE Loss: 1.0187, Cosine Similarity Loss: 0.8279
# Epoch 157/300, NLL Loss: -56.3336, MSE Loss: 1.6228, MAE Loss: 1.0053, Cosine Similarity Loss: 0.8293
# Epoch 158/300, NLL Loss: -56.0714, MSE Loss: 1.6175, MAE Loss: 1.0041, Cosine Similarity Loss: 0.8110
# Epoch 159/300, NLL Loss: -58.9651, MSE Loss: 1.6172, MAE Loss: 1.0053, Cosine Similarity Loss: 0.8275
# Epoch 160/300, NLL Loss: -56.2772, MSE Loss: 1.6825, MAE Loss: 1.0233, Cosine Similarity Loss: 0.8329
# Epoch 161/300, NLL Loss: -57.4367, MSE Loss: 1.5897, MAE Loss: 0.9956, Cosine Similarity Loss: 0.8113
# Epoch 162/300, NLL Loss: -56.1330, MSE Loss: 1.6875, MAE Loss: 1.0259, Cosine Similarity Loss: 0.8409
# Epoch 163/300, NLL Loss: -57.3680, MSE Loss: 1.6062, MAE Loss: 1.0022, Cosine Similarity Loss: 0.8179
# Epoch 164/300, NLL Loss: -56.9727, MSE Loss: 1.6569, MAE Loss: 1.0151, Cosine Similarity Loss: 0.8309
# Epoch 165/300, NLL Loss: -57.7264, MSE Loss: 1.5988, MAE Loss: 0.9978, Cosine Similarity Loss: 0.8146
# Epoch 166/300, NLL Loss: -57.8869, MSE Loss: 1.6769, MAE Loss: 1.0201, Cosine Similarity Loss: 0.8318
# Epoch 167/300, NLL Loss: -57.1131, MSE Loss: 1.6157, MAE Loss: 1.0063, Cosine Similarity Loss: 0.8161
# Epoch 168/300, NLL Loss: -57.6933, MSE Loss: 1.6332, MAE Loss: 1.0074, Cosine Similarity Loss: 0.8282
# Epoch 169/300, NLL Loss: -57.1351, MSE Loss: 1.6480, MAE Loss: 1.0142, Cosine Similarity Loss: 0.8204
# Epoch 170/300, NLL Loss: -57.2465, MSE Loss: 1.6572, MAE Loss: 1.0189, Cosine Similarity Loss: 0.8337
# Epoch 171/300, NLL Loss: -56.1444, MSE Loss: 1.6287, MAE Loss: 1.0082, Cosine Similarity Loss: 0.8171
# Epoch 172/300, NLL Loss: -57.6715, MSE Loss: 1.6228, MAE Loss: 1.0047, Cosine Similarity Loss: 0.8280
# Epoch 173/300, NLL Loss: -58.1340, MSE Loss: 1.6285, MAE Loss: 1.0078, Cosine Similarity Loss: 0.8192
# Epoch 174/300, NLL Loss: -56.5772, MSE Loss: 1.6591, MAE Loss: 1.0180, Cosine Similarity Loss: 0.8290
# Epoch 175/300, NLL Loss: -56.3583, MSE Loss: 1.6535, MAE Loss: 1.0148, Cosine Similarity Loss: 0.8304
# Epoch 176/300, NLL Loss: -58.0400, MSE Loss: 1.6180, MAE Loss: 1.0032, Cosine Similarity Loss: 0.8177
# Epoch 177/300, NLL Loss: -58.9470, MSE Loss: 1.6356, MAE Loss: 1.0100, Cosine Similarity Loss: 0.8339
# Epoch 178/300, NLL Loss: -56.0029, MSE Loss: 1.6602, MAE Loss: 1.0168, Cosine Similarity Loss: 0.8209
# Epoch 179/300, NLL Loss: -59.5189, MSE Loss: 1.6216, MAE Loss: 1.0054, Cosine Similarity Loss: 0.8297
# Epoch 180/300, NLL Loss: -57.3490, MSE Loss: 1.6570, MAE Loss: 1.0167, Cosine Similarity Loss: 0.8253
# Epoch 181/300, NLL Loss: -58.5508, MSE Loss: 1.6274, MAE Loss: 1.0059, Cosine Similarity Loss: 0.8206
# Epoch 182/300, NLL Loss: -59.6750, MSE Loss: 1.6266, MAE Loss: 1.0085, Cosine Similarity Loss: 0.8264
# Epoch 183/300, NLL Loss: -59.4509, MSE Loss: 1.6439, MAE Loss: 1.0119, Cosine Similarity Loss: 0.8273
# Epoch 184/300, NLL Loss: -58.7731, MSE Loss: 1.6405, MAE Loss: 1.0115, Cosine Similarity Loss: 0.8236
# Epoch 185/300, NLL Loss: -60.2300, MSE Loss: 1.6201, MAE Loss: 1.0054, Cosine Similarity Loss: 0.8261
# Epoch 186/300, NLL Loss: -59.8499, MSE Loss: 1.6496, MAE Loss: 1.0143, Cosine Similarity Loss: 0.8244
# Epoch 187/300, NLL Loss: -59.4585, MSE Loss: 1.6163, MAE Loss: 1.0039, Cosine Similarity Loss: 0.8161
# Epoch 188/300, NLL Loss: -60.0236, MSE Loss: 1.6482, MAE Loss: 1.0154, Cosine Similarity Loss: 0.8318
# Epoch 189/300, NLL Loss: -58.6615, MSE Loss: 1.6404, MAE Loss: 1.0106, Cosine Similarity Loss: 0.8210
# Epoch 190/300, NLL Loss: -60.1260, MSE Loss: 1.6361, MAE Loss: 1.0090, Cosine Similarity Loss: 0.8239
# Epoch 191/300, NLL Loss: -60.0820, MSE Loss: 1.6584, MAE Loss: 1.0168, Cosine Similarity Loss: 0.8342
# Epoch 192/300, NLL Loss: -59.1604, MSE Loss: 1.6445, MAE Loss: 1.0124, Cosine Similarity Loss: 0.8190
# Epoch 193/300, NLL Loss: -59.8370, MSE Loss: 1.6285, MAE Loss: 1.0077, Cosine Similarity Loss: 0.8334
# Epoch 194/300, NLL Loss: -59.9851, MSE Loss: 1.6295, MAE Loss: 1.0093, Cosine Similarity Loss: 0.8157
# Epoch 195/300, NLL Loss: -60.2808, MSE Loss: 1.6458, MAE Loss: 1.0117, Cosine Similarity Loss: 0.8322
# Epoch 196/300, NLL Loss: -60.1337, MSE Loss: 1.6489, MAE Loss: 1.0115, Cosine Similarity Loss: 0.8277
# Epoch 197/300, NLL Loss: -61.9892, MSE Loss: 1.6385, MAE Loss: 1.0122, Cosine Similarity Loss: 0.8289
# Epoch 198/300, NLL Loss: -59.7055, MSE Loss: 1.6507, MAE Loss: 1.0151, Cosine Similarity Loss: 0.8232
# Epoch 199/300, NLL Loss: -59.3349, MSE Loss: 1.6499, MAE Loss: 1.0142, Cosine Similarity Loss: 0.8318
# Epoch 200/300, NLL Loss: -61.3590, MSE Loss: 1.6071, MAE Loss: 1.0006, Cosine Similarity Loss: 0.8206
# Epoch 201/300, NLL Loss: -68.0286, MSE Loss: 1.5469, MAE Loss: 0.9793, Cosine Similarity Loss: 0.8218
# Epoch 202/300, NLL Loss: -86.7858, MSE Loss: 1.3912, MAE Loss: 0.9303, Cosine Similarity Loss: 0.8026
# Epoch 203/300, NLL Loss: -94.2956, MSE Loss: 1.5039, MAE Loss: 0.9718, Cosine Similarity Loss: 0.8121
# Epoch 204/300, NLL Loss: -97.0042, MSE Loss: 1.5209, MAE Loss: 0.9742, Cosine Similarity Loss: 0.8213
# Epoch 205/300, NLL Loss: -98.5041, MSE Loss: 1.5110, MAE Loss: 0.9700, Cosine Similarity Loss: 0.8039
# Epoch 206/300, NLL Loss: -99.8271, MSE Loss: 1.5422, MAE Loss: 0.9807, Cosine Similarity Loss: 0.8180
# Epoch 207/300, NLL Loss: -102.4581, MSE Loss: 1.5160, MAE Loss: 0.9703, Cosine Similarity Loss: 0.8111
# Epoch 208/300, NLL Loss: -102.6116, MSE Loss: 1.5580, MAE Loss: 0.9866, Cosine Similarity Loss: 0.8182
# Epoch 209/300, NLL Loss: -103.2376, MSE Loss: 1.5483, MAE Loss: 0.9815, Cosine Similarity Loss: 0.8111
# Epoch 210/300, NLL Loss: -103.3880, MSE Loss: 1.5653, MAE Loss: 0.9883, Cosine Similarity Loss: 0.8179
# Epoch 211/300, NLL Loss: -103.5178, MSE Loss: 1.5646, MAE Loss: 0.9859, Cosine Similarity Loss: 0.8158
# Epoch 212/300, NLL Loss: -103.9442, MSE Loss: 1.5834, MAE Loss: 0.9920, Cosine Similarity Loss: 0.8302
# Epoch 213/300, NLL Loss: -104.3819, MSE Loss: 1.5462, MAE Loss: 0.9797, Cosine Similarity Loss: 0.8062
# Epoch 214/300, NLL Loss: -105.4352, MSE Loss: 1.5894, MAE Loss: 0.9957, Cosine Similarity Loss: 0.8276
# Epoch 215/300, NLL Loss: -103.7146, MSE Loss: 1.5852, MAE Loss: 0.9947, Cosine Similarity Loss: 0.8106
# Epoch 216/300, NLL Loss: -105.3162, MSE Loss: 1.5854, MAE Loss: 0.9942, Cosine Similarity Loss: 0.8290
# Epoch 217/300, NLL Loss: -103.4279, MSE Loss: 1.5950, MAE Loss: 0.9970, Cosine Similarity Loss: 0.8160
# Epoch 218/300, NLL Loss: -106.3652, MSE Loss: 1.5609, MAE Loss: 0.9861, Cosine Similarity Loss: 0.8176
# Epoch 219/300, NLL Loss: -104.8961, MSE Loss: 1.6058, MAE Loss: 0.9998, Cosine Similarity Loss: 0.8217
# Epoch 220/300, NLL Loss: -106.0041, MSE Loss: 1.5940, MAE Loss: 0.9973, Cosine Similarity Loss: 0.8256
# Epoch 221/300, NLL Loss: -107.0299, MSE Loss: 1.5788, MAE Loss: 0.9916, Cosine Similarity Loss: 0.8183
# Epoch 222/300, NLL Loss: -106.1282, MSE Loss: 1.6054, MAE Loss: 0.9998, Cosine Similarity Loss: 0.8297
# Epoch 223/300, NLL Loss: -104.5982, MSE Loss: 1.6143, MAE Loss: 1.0023, Cosine Similarity Loss: 0.8219
# Epoch 224/300, NLL Loss: -104.9966, MSE Loss: 1.6022, MAE Loss: 1.0004, Cosine Similarity Loss: 0.8206
# Epoch 225/300, NLL Loss: -105.7894, MSE Loss: 1.5922, MAE Loss: 0.9954, Cosine Similarity Loss: 0.8218
# Epoch 226/300, NLL Loss: -105.9414, MSE Loss: 1.6001, MAE Loss: 0.9981, Cosine Similarity Loss: 0.8213
# Epoch 227/300, NLL Loss: -105.9120, MSE Loss: 1.6088, MAE Loss: 1.0002, Cosine Similarity Loss: 0.8264
# Epoch 228/300, NLL Loss: -107.4397, MSE Loss: 1.5901, MAE Loss: 0.9949, Cosine Similarity Loss: 0.8220
# Epoch 229/300, NLL Loss: -107.4294, MSE Loss: 1.5934, MAE Loss: 0.9950, Cosine Similarity Loss: 0.8209
# Epoch 230/300, NLL Loss: -106.1642, MSE Loss: 1.6177, MAE Loss: 1.0052, Cosine Similarity Loss: 0.8206
# Epoch 231/300, NLL Loss: -104.9802, MSE Loss: 1.6235, MAE Loss: 1.0061, Cosine Similarity Loss: 0.8277
# Epoch 232/300, NLL Loss: -106.6523, MSE Loss: 1.6143, MAE Loss: 1.0050, Cosine Similarity Loss: 0.8326
# Epoch 233/300, NLL Loss: -107.7166, MSE Loss: 1.5897, MAE Loss: 0.9947, Cosine Similarity Loss: 0.8198
# Epoch 234/300, NLL Loss: -106.2788, MSE Loss: 1.6392, MAE Loss: 1.0091, Cosine Similarity Loss: 0.8309
# Epoch 235/300, NLL Loss: -107.3208, MSE Loss: 1.5836, MAE Loss: 0.9937, Cosine Similarity Loss: 0.8148
# Epoch 236/300, NLL Loss: -108.0802, MSE Loss: 1.6203, MAE Loss: 1.0045, Cosine Similarity Loss: 0.8312
# Epoch 237/300, NLL Loss: -107.0686, MSE Loss: 1.6205, MAE Loss: 1.0045, Cosine Similarity Loss: 0.8279
# Epoch 238/300, NLL Loss: -108.6541, MSE Loss: 1.5940, MAE Loss: 0.9957, Cosine Similarity Loss: 0.8181
# Epoch 239/300, NLL Loss: -107.6271, MSE Loss: 1.6404, MAE Loss: 1.0103, Cosine Similarity Loss: 0.8314
# Epoch 240/300, NLL Loss: -105.8521, MSE Loss: 1.6320, MAE Loss: 1.0083, Cosine Similarity Loss: 0.8215
# Epoch 241/300, NLL Loss: -106.7250, MSE Loss: 1.6203, MAE Loss: 1.0030, Cosine Similarity Loss: 0.8273
# Epoch 242/300, NLL Loss: -106.0098, MSE Loss: 1.6289, MAE Loss: 1.0081, Cosine Similarity Loss: 0.8288
# Epoch 243/300, NLL Loss: -107.9079, MSE Loss: 1.5934, MAE Loss: 0.9950, Cosine Similarity Loss: 0.8218
# Epoch 244/300, NLL Loss: -107.9835, MSE Loss: 1.6222, MAE Loss: 1.0054, Cosine Similarity Loss: 0.8312
# Epoch 245/300, NLL Loss: -108.6947, MSE Loss: 1.6075, MAE Loss: 1.0015, Cosine Similarity Loss: 0.8211
# Epoch 246/300, NLL Loss: -107.8025, MSE Loss: 1.6214, MAE Loss: 1.0063, Cosine Similarity Loss: 0.8252
# Epoch 247/300, NLL Loss: -106.6097, MSE Loss: 1.6473, MAE Loss: 1.0133, Cosine Similarity Loss: 0.8288
# Epoch 248/300, NLL Loss: -107.7811, MSE Loss: 1.6067, MAE Loss: 1.0041, Cosine Similarity Loss: 0.8233
# Epoch 249/300, NLL Loss: -108.6269, MSE Loss: 1.6269, MAE Loss: 1.0072, Cosine Similarity Loss: 0.8297
# Epoch 250/300, NLL Loss: -108.4593, MSE Loss: 1.6173, MAE Loss: 1.0028, Cosine Similarity Loss: 0.8227
# Epoch 251/300, NLL Loss: -108.8493, MSE Loss: 1.6249, MAE Loss: 1.0084, Cosine Similarity Loss: 0.8263
# Epoch 252/300, NLL Loss: -107.3445, MSE Loss: 1.6296, MAE Loss: 1.0084, Cosine Similarity Loss: 0.8226
# Epoch 253/300, NLL Loss: -107.8070, MSE Loss: 1.6165, MAE Loss: 1.0026, Cosine Similarity Loss: 0.8266
# Epoch 254/300, NLL Loss: -110.3649, MSE Loss: 1.5871, MAE Loss: 0.9953, Cosine Similarity Loss: 0.8243
# Epoch 255/300, NLL Loss: -109.1572, MSE Loss: 1.6370, MAE Loss: 1.0082, Cosine Similarity Loss: 0.8303
# Epoch 256/300, NLL Loss: -109.5859, MSE Loss: 1.6326, MAE Loss: 1.0071, Cosine Similarity Loss: 0.8305
# Epoch 257/300, NLL Loss: -109.4240, MSE Loss: 1.6089, MAE Loss: 0.9974, Cosine Similarity Loss: 0.8164
# Epoch 258/300, NLL Loss: -109.7521, MSE Loss: 1.6087, MAE Loss: 1.0006, Cosine Similarity Loss: 0.8276
# Epoch 259/300, NLL Loss: -109.2599, MSE Loss: 1.6337, MAE Loss: 1.0085, Cosine Similarity Loss: 0.8300
# Epoch 260/300, NLL Loss: -108.5481, MSE Loss: 1.6281, MAE Loss: 1.0084, Cosine Similarity Loss: 0.8265
# Epoch 261/300, NLL Loss: -109.4992, MSE Loss: 1.6150, MAE Loss: 1.0031, Cosine Similarity Loss: 0.8252
# Epoch 262/300, NLL Loss: -108.0837, MSE Loss: 1.6719, MAE Loss: 1.0206, Cosine Similarity Loss: 0.8387
# Epoch 263/300, NLL Loss: -107.5942, MSE Loss: 1.6229, MAE Loss: 1.0076, Cosine Similarity Loss: 0.8219
# Epoch 264/300, NLL Loss: -109.3626, MSE Loss: 1.6236, MAE Loss: 1.0047, Cosine Similarity Loss: 0.8320
# Epoch 265/300, NLL Loss: -107.8599, MSE Loss: 1.6298, MAE Loss: 1.0076, Cosine Similarity Loss: 0.8228
# Epoch 266/300, NLL Loss: -108.6205, MSE Loss: 1.6347, MAE Loss: 1.0056, Cosine Similarity Loss: 0.8327
# Epoch 267/300, NLL Loss: -108.0656, MSE Loss: 1.6324, MAE Loss: 1.0087, Cosine Similarity Loss: 0.8232
# Epoch 268/300, NLL Loss: -109.9440, MSE Loss: 1.6141, MAE Loss: 1.0033, Cosine Similarity Loss: 0.8269
# Epoch 269/300, NLL Loss: -110.3551, MSE Loss: 1.6174, MAE Loss: 1.0022, Cosine Similarity Loss: 0.8250
# Epoch 270/300, NLL Loss: -108.3645, MSE Loss: 1.6690, MAE Loss: 1.0200, Cosine Similarity Loss: 0.8355
# Epoch 271/300, NLL Loss: -108.4646, MSE Loss: 1.6090, MAE Loss: 1.0001, Cosine Similarity Loss: 0.8185
# Epoch 272/300, NLL Loss: -111.5018, MSE Loss: 1.6054, MAE Loss: 0.9991, Cosine Similarity Loss: 0.8293
# Epoch 273/300, NLL Loss: -108.1349, MSE Loss: 1.6777, MAE Loss: 1.0208, Cosine Similarity Loss: 0.8322
# Epoch 274/300, NLL Loss: -108.3073, MSE Loss: 1.6326, MAE Loss: 1.0101, Cosine Similarity Loss: 0.8282
# Epoch 275/300, NLL Loss: -110.6681, MSE Loss: 1.6047, MAE Loss: 0.9996, Cosine Similarity Loss: 0.8251
# Epoch 276/300, NLL Loss: -109.8436, MSE Loss: 1.6455, MAE Loss: 1.0129, Cosine Similarity Loss: 0.8330
# Epoch 277/300, NLL Loss: -109.9700, MSE Loss: 1.6363, MAE Loss: 1.0106, Cosine Similarity Loss: 0.8258
# Epoch 278/300, NLL Loss: -108.6856, MSE Loss: 1.6442, MAE Loss: 1.0106, Cosine Similarity Loss: 0.8283
# Epoch 279/300, NLL Loss: -109.3404, MSE Loss: 1.6160, MAE Loss: 1.0031, Cosine Similarity Loss: 0.8233
# Epoch 280/300, NLL Loss: -108.5921, MSE Loss: 1.6516, MAE Loss: 1.0159, Cosine Similarity Loss: 0.8336
# Epoch 281/300, NLL Loss: -108.5463, MSE Loss: 1.6512, MAE Loss: 1.0137, Cosine Similarity Loss: 0.8332
# Epoch 282/300, NLL Loss: -110.4235, MSE Loss: 1.6049, MAE Loss: 1.0036, Cosine Similarity Loss: 0.8217
# Epoch 283/300, NLL Loss: -110.7760, MSE Loss: 1.6260, MAE Loss: 1.0059, Cosine Similarity Loss: 0.8317
# Epoch 284/300, NLL Loss: -109.1829, MSE Loss: 1.6447, MAE Loss: 1.0136, Cosine Similarity Loss: 0.8235
# Epoch 285/300, NLL Loss: -109.4182, MSE Loss: 1.6270, MAE Loss: 1.0073, Cosine Similarity Loss: 0.8291
# Epoch 286/300, NLL Loss: -109.1316, MSE Loss: 1.6431, MAE Loss: 1.0099, Cosine Similarity Loss: 0.8374
# Epoch 287/300, NLL Loss: -110.1885, MSE Loss: 1.6087, MAE Loss: 1.0005, Cosine Similarity Loss: 0.8195
# Epoch 288/300, NLL Loss: -109.0030, MSE Loss: 1.6651, MAE Loss: 1.0174, Cosine Similarity Loss: 0.8389
# Epoch 289/300, NLL Loss: -111.5567, MSE Loss: 1.5914, MAE Loss: 0.9945, Cosine Similarity Loss: 0.8232
# Epoch 290/300, NLL Loss: -110.4837, MSE Loss: 1.6309, MAE Loss: 1.0073, Cosine Similarity Loss: 0.8235
# Epoch 291/300, NLL Loss: -109.1571, MSE Loss: 1.6742, MAE Loss: 1.0208, Cosine Similarity Loss: 0.8372
# Epoch 292/300, NLL Loss: -110.2469, MSE Loss: 1.6041, MAE Loss: 1.0010, Cosine Similarity Loss: 0.8225
# Epoch 293/300, NLL Loss: -108.5774, MSE Loss: 1.6592, MAE Loss: 1.0167, Cosine Similarity Loss: 0.8316
# Epoch 294/300, NLL Loss: -110.7115, MSE Loss: 1.6224, MAE Loss: 1.0042, Cosine Similarity Loss: 0.8269
# Epoch 295/300, NLL Loss: -111.0858, MSE Loss: 1.6435, MAE Loss: 1.0099, Cosine Similarity Loss: 0.8366
# Epoch 296/300, NLL Loss: -110.0973, MSE Loss: 1.6227, MAE Loss: 1.0071, Cosine Similarity Loss: 0.8204
# Epoch 297/300, NLL Loss: -110.2389, MSE Loss: 1.6329, MAE Loss: 1.0085, Cosine Similarity Loss: 0.8310
# Epoch 298/300, NLL Loss: -111.3206, MSE Loss: 1.6260, MAE Loss: 1.0057, Cosine Similarity Loss: 0.8273
# Epoch 299/300, NLL Loss: -109.3906, MSE Loss: 1.6655, MAE Loss: 1.0171, Cosine Similarity Loss: 0.8357
# Epoch 300/300, NLL Loss: -112.2912, MSE Loss: 1.5972, MAE Loss: 0.9973, Cosine Similarity Loss: 0.8211

# %%
torch.save(model.state_dict(), "generated/glow_model.pt")

# %% [markdown]
# # 5. Generate and Visualize

# %%
def generate_synthetic_data(model, scaler, le, samples_per_class_dict):
    model.eval()
    zs, labels = [], []

    for class_name, n_samples in samples_per_class_dict.items():
        class_idx = le.transform([class_name])[0]
        z = torch.randn(n_samples, input_dim).to(device)
        y = torch.full((n_samples,), class_idx, dtype=torch.long).to(device)
        x_fake = model.inverse(z, y).detach().cpu().numpy()
        zs.append(x_fake)
        labels.extend([class_idx] * n_samples)

    X_fake = np.vstack(zs)
    y_fake = np.array(labels)
    X_fake_rescaled = scaler.inverse_transform(X_fake)

    df_fake = pd.DataFrame(X_fake_rescaled, columns=feature_names)
    df_fake["Cell_type"] = le.inverse_transform(y_fake)
    df_fake.to_csv("generated/fake_data.csv", index=False)
    print("✅ Saved synthetic data to 'generated/fake_data.csv'")
    return df_fake

samples_per_class_dict = {
    "PreB": 0,
    "B": 250,
    "T": 250,
    "PreT": 250
}

df_fake = generate_synthetic_data(model, scaler, le, samples_per_class_dict)

X_fake = scaler.transform(df_fake[feature_names])
y_fake = le.transform(df_fake["Cell_type"])
# Out:
# ✅ Saved synthetic data to 'generated/fake_data.csv'
# /home/thomas/miniconda3/envs/DeepN/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
# %% [markdown]
# ## 7. Visualization: PCA Per Class + Feature Distribution

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

def plot_pca_per_class(X_real, y_real, X_fake, y_fake, class_names, scaler, label_encoder):
    pca = PCA(n_components=2)
    for i, class_name in enumerate(class_names):
        real_mask = y_real == i
        fake_mask = y_fake == i

        if np.sum(real_mask) == 0 or np.sum(fake_mask) == 0:
            continue

        Xr = X_real[real_mask]
        Xf = X_fake[fake_mask]
        X_combined = np.vstack([Xr, Xf])
        X_pca = pca.fit_transform(X_combined)

        Xr_pca = X_pca[:len(Xr)]
        Xf_pca = X_pca[len(Xr):]

        plt.figure(figsize=(14, 10))
        plt.scatter(Xr_pca[:, 0], Xr_pca[:, 1], alpha=0.6, label="Real", c='blue')
        plt.scatter(Xf_pca[:, 0], Xf_pca[:, 1], alpha=0.6, label="Fake", c='orange')
        plt.title(f"PCA: {class_name}")
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"generated/pca_{class_name}.png")
        plt.close()

def plot_feature_distributions_grid(df_real, df_fake, features, max_features=24, n_cols=4):
    selected_features = features[:max_features]
    n_feats = len(selected_features)
    n_rows = (n_feats + n_cols - 1) // n_cols
    plt.figure(figsize=(14, 10))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 6, n_rows * 3))
    axes = axes.flatten()

    for idx, feature in enumerate(selected_features):
        ax = axes[idx]
        sns.kdeplot(data=df_real, x=feature, label="Real", fill=True, color="blue", alpha=0.5, ax=ax)
        sns.kdeplot(data=df_fake, x=feature, label="Fake", fill=True, color="orange", alpha=0.5, ax=ax)
        ax.set_title(feature)
        ax.legend()

    # Hide any empty subplots
    for i in range(n_feats, len(axes)):
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.savefig("generated/feature_distributions_grid.png")
    plt.show()
    plt.close()
    print(f"✅ Feature distribution grid saved as 'generated/feature_distributions_grid.png'")



def plot_feature_distributions(X_real_df, X_fake_df, features, class_names):
    for feature in features:
        plt.figure(figsize=(14, 10))
        sns.kdeplot(data=X_real_df, x=feature, label="Real", fill=True, color="blue", alpha=0.5)
        sns.kdeplot(data=X_fake_df, x=feature, label="Fake", fill=True, color="orange", alpha=0.5)
        plt.title(f"Feature Distribution: {feature}")
        plt.legend()
        plt.tight_layout()
        plt.savefig(f"generated/feature_dist_{feature}.png")
        plt.show()
        plt.close()

from sklearn.metrics.pairwise import rbf_kernel
import numpy as np

def compute_mmd_rbf(X_real, X_fake, gamma=1.0):
    """Compute Maximum Mean Discrepancy (MMD) between real and fake using RBF kernel."""
    XX = rbf_kernel(X_real, X_real, gamma=gamma)
    YY = rbf_kernel(X_fake, X_fake, gamma=gamma)
    XY = rbf_kernel(X_real, X_fake, gamma=gamma)

    mmd = XX.mean() + YY.mean() - 2 * XY.mean()
    print(f"✅ MMD (RBF, γ={gamma}) = {mmd:.5f}")
    return mmd

from scipy.stats import wasserstein_distance

def compute_avg_wasserstein_distance(df_real, df_fake, feature_names):
    distances = []
    for feature in feature_names:
        d = wasserstein_distance(df_real[feature], df_fake[feature])
        distances.append(d)
    avg_wass = np.mean(distances)
    print(f"🌊 Avg. 1D Wasserstein Distance = {avg_wass:.5f}")
    return avg_wass

from sklearn.metrics.pairwise import cosine_similarity

def compute_mean_cosine_similarity(X_real, X_fake, n_samples=1000):
    """Compute mean cosine similarity between randomly paired real and fake samples."""
    n = min(len(X_real), len(X_fake), n_samples)
    Xr = X_real[:n]
    Xf = X_fake[:n]
    similarities = cosine_similarity(Xr, Xf)
    mean_cos_sim = np.mean(np.diag(similarities))
    print(f"🧭 Mean Cosine Similarity = {mean_cos_sim:.5f}")
    return mean_cos_sim

from sklearn.neighbors import NearestNeighbors

def compute_knn_realism_score(X_real, X_fake, k=5):
    """Compute realism score: fraction of real samples in k-NN of each fake point."""
    X = np.vstack([X_real, X_fake])
    y = np.array([1]*len(X_real) + [0]*len(X_fake))  # 1=real, 0=fake
    knn = NearestNeighbors(n_neighbors=k+1)  # +1 because the point itself is included
    knn.fit(X)
    
    indices = knn.kneighbors(X_fake, return_distance=False)[:, 1:]  # exclude self
    neighbor_labels = y[indices]
    realism_scores = neighbor_labels.mean(axis=1)
    avg_realism = realism_scores.mean()
    print(f"🔍 k-NN Realism Score (k={k}) = {avg_realism:.5f}")
    return avg_realism

# Prepare for plotting
df_real = pd.DataFrame(scaler.inverse_transform(X_scaled), columns=feature_names)
df_real["Cell_type"] = le.inverse_transform(y)
df_fake = pd.read_csv("generated/fake_data.csv")
X_real = scaler.transform(df_real[feature_names])
y_real = le.transform(df_real["Cell_type"])
X_fake = scaler.transform(df_fake[feature_names])
y_fake = le.transform(df_fake["Cell_type"])

mmd = compute_mmd_rbf(X_scaled, X_fake)
compute_avg_wasserstein_distance(df_real, df_fake, feature_names)
compute_mean_cosine_similarity(X_real, X_fake)
compute_knn_realism_score(X_real, X_fake, k=5)

plot_pca_per_class(X_scaled, y, X_fake, y_fake, label_names, scaler, le)
#plot_feature_distributions(df_real, df_fake, feature_names, label_names)
plot_feature_distributions_grid(df_real, df_fake, feature_names, max_features=30, n_cols=6)
# Out:
# /home/thomas/miniconda3/envs/DeepN/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/thomas/miniconda3/envs/DeepN/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# ✅ MMD (RBF, γ=1.0) = 0.00296
# 🌊 Avg. 1D Wasserstein Distance = 0.19915
# 🧭 Mean Cosine Similarity = 0.01358
# 🔍 k-NN Realism Score (k=5) = 0.00507
# ✅ Feature distribution grid saved as 'generated/feature_distributions_grid.png'
